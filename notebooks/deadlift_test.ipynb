# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt
import sys
sys.path.append('..')  # Replace '/path/to/FSM_deadlift/module' with the actual path to the FSM_deadlift module

import numpy as np
from thresholds import get_thresholds

from dotenv import load_dotenv
import os
from FSM_deadlift import FSM_deadlift

# Carga las variables de entorno
load_dotenv()

# mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose


username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")
ip = os.getenv("IP_CAM_ADDRESS")
rtsp_port = os.getenv("IP_CAM_RTSP_PORT")
rtsp_path = os.getenv("IP_CAM_RTSP_PATH")

cap = cv2.VideoCapture(0) #IP Camera
FSM = FSM_deadlift(get_thresholds(3))
puntuacion= list()
with mp_pose.Pose(
    static_image_mode=False) as pose:   #PARA VIDEOS PONER FALSE /TRUE ES PARA FOTOS
        while True:
            ret, frame = cap.read()
            # frame = cv2.resize(frame, (960, 540))
            # print(frame)
                    
            
            #print (ret)
            #frame_rgb= cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
            FSM_deadlift.process(FSM, frame, pose)
            #frame = cv2.flip(frame,1)  #espejo a la camara 
            #heigth, width, _ = frame.shape 
            
            #results = pose.process(frame_rgb)

            #if results.pose_landmarks is not None:
            cv2.imshow("Frame", frame)
            if cv2.waitKey(1) & 0xFF == 27:
                break
             
cap.release()
cv2.destroyAllWindows()
# Out:
# 2024-08-01 13:33:23.831511: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-01 13:33:27.811 python[31766:11829215] WARNING: AVCaptureDeviceTypeExternal is deprecated for Continuity Cameras. Please use AVCaptureDeviceTypeContinuityCamera and add NSCameraUseContinuityCameraDeviceType to your Info.plist.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt
import sys
sys.path.append('..')  # Replace '/path/to/FSM_deadlift/module' with the actual path to the FSM_deadlift module

import numpy as np
from thresholds import get_thresholds

from dotenv import load_dotenv
import os
from FSM_deadlift import FSM_deadlift

# Carga las variables de entorno
load_dotenv()

# mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose


username = os.getenv("USERNAME")
password = os.getenv("PASSWORD")
ip = os.getenv("IP_CAM_ADDRESS")
rtsp_port = os.getenv("IP_CAM_RTSP_PORT")
rtsp_path = os.getenv("IP_CAM_RTSP_PATH")

cap = cv2.VideoCapture(f'rtsp://{username}:{password}@{ip}:{rtsp_port}/{rtsp_path}') #IP Camera
FSM = FSM_deadlift(get_thresholds(3))
puntuacion= list()
with mp_pose.Pose(
    static_image_mode=False) as pose:   #PARA VIDEOS PONER FALSE /TRUE ES PARA FOTOS
        while True:
            ret, frame = cap.read()
            frame = cv2.resize(frame, (960, 540))
            # print(frame)
                    
            
            #print (ret)
            #frame_rgb= cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
            FSM_deadlift.process(FSM, frame, pose)
            print(FSM_deadlift._show_state_tracker_info(FSM))
            #frame = cv2.flip(frame,1)  #espejo a la camara 
            #heigth, width, _ = frame.shape 
            
            #results = pose.process(frame_rgb)

            #if results.pose_landmarks is not None:
            cv2.imshow("Frame", frame)
            if cv2.waitKey(1) & 0xFF == 27:
                break
             
cap.release()
cv2.destroyAllWindows()
# Out:
# 2024-08-09 19:20:15.717031: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# SEQUENCE [],
#                 CURRENT STATE None,
#                 PREVIOUS STATE None
#
#                 COUNTERS: (0, 0)
#
# SEQUENCE [],
#                 CURRENT STATE None,
#                 PREVIOUS STATE None
#
#                 COUNTERS: (0, 0)
#
# SEQUENCE [],
#                 CURRENT STATE None,
#                 PREVIOUS STATE None
#
#                 COUNTERS: (0, 0)
#
# SEQUENCE [],
#                 CURRENT STATE None,
#                 PREVIOUS STATE None
#
#                 COUNTERS: (0, 0)
#
# SEQUENCE [],
#                 CURRENT STATE None,
#                 PREVIOUS STATE None
#
# ...

# %%
import numpy as np

def find_angle_with_negs(p1, p2, ref_pt=np.array([0, 0])):
    """Find the angle between two points with respect to a vertical reference.
    Args:
        p1 (np.array): First point as an array [x, y].
        p2 (np.array): Second point as an array [x, y].
        ref_pt (np.array, optional): Reference point. Defaults to np.array([0,0]).
    Returns:
        float: Angle in degrees between -180 and 180.
    """
    p1_ref = p1 - ref_pt
    p2_ref = p2 - ref_pt

    # Vector from reference point to the origin, which is the vertical reference
    vertical = np.array([0, 1])

    # Calculate angle with respect to the vertical reference
    angle_p1 = np.arctan2(p1_ref[1], p1_ref[0])
    angle_p2 = np.arctan2(p2_ref[1], p2_ref[0])

    # Calculate the difference between the two angles
    theta = np.degrees(angle_p2 - angle_p1)

    # Normalize the angle to the range -180 to 180
    if theta > 180:
        theta -= 360
    elif theta < -180:
        theta += 360

    return theta

# Example usage:
p1 = np.array([1, 2])
p2 = np.array([3, 4])
ref_pt = np.array([0, 0])

angle = find_angle(p1, p2, ref_pt)
print(angle)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 38
#      35 p2 = np.array([3, 4])
#      36 ref_pt = np.array([0, 0])
# ---> 38 angle = find_angle(p1, p2, ref_pt)
#      39 print(angle)
#
# NameError: name 'find_angle' is not defined
